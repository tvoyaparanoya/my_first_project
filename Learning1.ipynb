# %% [markdown]
# <a href="https://colab.research.google.com/github/tvoyaparanoya/my_first_project/blob/main/Learning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(1 + 1)
# Out:
# 2

# %%
print(2 - 1, 5 + 6)
# Out:
# 1 11

# %%
1 + 1
# Out:
# 2

# %%
1 + 1
2 - 1
# Out:
# 1

# %%
print(1 + 1)
print(2 - 1)
# Out:
# 2
# 1

# %%
5 * 6
# Out:
# 30

# %%
10 / 4
# Out:
# 2.5

# %%
10 // 4
# Out:
# 2

# %%
2 ** 5000
# Out:
# ...

# %%
-4 % 3
# Out:
# 2

# %%
(5 - 3) + 2 * 6
# Out:
# 14

# %%
a = 10 + 20
b = a * 30
c = round(a / b, 4)
print('Ответ: ', c)
# Out:
# Ответ:  0.0333

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# # Row

# %%
my_string_1 = 'He said: "It is zhost"'

# %%
my_string_2 = "Hello Demons!"

# %%
my_string_1
# Out:
# 'He said: "It is zhost"'

# %%
my_string_2
# Out:
# 'Hello Demons!'

# %%
2 > 1
# Out:
# True

# %%
10 < 9
# Out:
# False

# %%
10 > 10
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
7 == 7
# Out:
# True

# %%
15 != 15
# Out:
# False

# %%
5 > 4 < 10
# Out:
# True

# %%
print('c' > 'a')
# Out:
# True

# %%
print('b' > 'B')
# Out:
# True

# %%
print('abc' > 'aba')
# Out:
# True

# %%
len('abc') > len('dfhjdfj')
# Out:
# False

# %%
'2020-05-01' < '2020-05-09'
# Out:
# True

# %%
'2019-12-31' < '2020-01-01'
# Out:
# True

# %%
'logs_2020-02-29.csv' < 'logs_2020-03-01.csv'
# Out:
# True

# %%
a = 1
b = 2

if a < b:
  print('Значение переменной a меньше b')
else:
  print('Значение переменной a больше b')
# Out:
# Значение переменной a меньше b

# %%
x = 5
if x % 2 == 0:
  print(x, '- четное число')

# %%
0 < 1 and 2 < 3
# Out:
# True

# %%
0 > 1 and 2 < 3
# Out:
# False

# %%
0 > 1 and 2 > 3
# Out:
# False

# %%
0 < 1 or 2 < 3
# Out:
# True

# %%
0 > 1 or 2 < 3
# Out:
# True

# %%
0 > 1 or 2 > 3
# Out:
# False

# %%
0 < 1
# Out:
# True

# %%
not 0 < 1
# Out:
# False

# %%
money_sum = 5
sum_to_pay = 10
today_is_holiday = False
days_to_pay = 15

should_notify = (
    money_sum < sum_to_pay and
                 (
                     (
                         days_to_pay < 10 and not today_is_holiday
                     )
                 or days_to_pay == 15
                  )
                 )

should_notify
# Out:
# True

# %%
height = 140
if height < 170:
  print('В танкисты')

print('Конец программы')
# Out:
# В танкисты
# Конец программы

# %%
height = 180
if height < 170:
  print('В танкисты')
else:
  print('В другие войска')
print('Конец программы')
# Out:
# В другие войска
# Конец программы

# %%
height = 175
if height < 170:
  print('В танкисты')
elif height < 180:
  print('На флот')
elif height < 200:
  print('В десантники')
else:
  print('В другие войска')
print('Конец программы')
# Out:
# На флот
# Конец программы

# %%
((9 > 7) and (2 < 4))
# Out:
# True

# %%
(8 == 8) or (6 !=6)
# Out:
# True

# %%
not(3 <= 1)
# Out:
# True

# %%
age = 17
height = 210
if height < 170 and age >= 18:
  print('В танкисты')
elif height < 180 and age >= 18:
  print('На флот')
elif height < 200 and age >= 18:
  print('В десантники')
else:
  print('В другие войска')
print('Конец программы')
# Out:
# В другие войска
# Конец программы

# %%
age = int(input('Введите возраст '))
if  age >= 18 and age <= 65:
  user_input = int(input('Введите рост '))
  if user_input < 170:
    print('В танкисты')
  elif user_input < 185:
    print('На флот')
  elif user_input < 200:
    print('В десантники')
  else:
    print('В другие войска')
else:
  print('Непризывной возраст')
print('Конец программы')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-981977710.py in <cell line: 0>()
# ----> 1 age = int(input('Введите возраст '))
#       2 if  age >= 18 and age <= 65:
#       3   user_input = int(input('Введите рост '))
#       4   if user_input < 170:
#       5     print('В танкисты')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
